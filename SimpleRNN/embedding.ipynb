# %%
from tensorflow.keras.preprocessing.text import one_hot # type: ignore

# %%
# sentences
sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]

# %%
#Define the vocabulary size
voc_size=10000

# %%
#One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[357, 9311, 8336, 365],
#  [357, 9311, 8336, 1198],
#  [357, 3108, 8336, 2548],
#  [7662, 5725, 3688, 17, 4309],
#  [7662, 5725, 3688, 17, 5315],
#  [3172, 357, 6844, 8336, 32],
#  [111, 896, 3783, 17]]

# %%
# word embedding

from tensorflow.keras.layers import Embedding  # type: ignore
from tensorflow.keras.utils import pad_sequences # type: ignore
from tensorflow.keras.models import Sequential # type: ignore

# %%
import numpy as np

# %%
# set squence lenght
sent_lenght=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_lenght)
print(embedded_docs)
# Out:
# [[   0    0    0    0  357 9311 8336  365]
#  [   0    0    0    0  357 9311 8336 1198]
#  [   0    0    0    0  357 3108 8336 2548]
#  [   0    0    0 7662 5725 3688   17 4309]
#  [   0    0    0 7662 5725 3688   17 5315]
#  [   0    0    0 3172  357 6844 8336   32]
#  [   0    0    0    0  111  896 3783   17]]

# %%
# feature representation
dim=10

# %%
dummy_input = np.zeros((1, sent_lenght), dtype=int)  # shape: (batch_size=1, sequence_length)
model(dummy_input) # type: ignore
model.summary() # type: ignore
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (7, 8, 10)             │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs) # type: ignore
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# array([[[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01024283,  0.03333897, -0.03597488, -0.03536908,
#          -0.01081369, -0.0326545 ,  0.03283647, -0.04393221,
#          -0.04876666,  0.00742389],
#         [-0.00184723, -0.01144005,  0.00779573, -0.02412662,
#           0.01283425,  0.00128699,  0.00562125, -0.0260524 ,
#           0.01661733, -0.01676977],
#         [ 0.03957203,  0.00710893, -0.0075979 , -0.04074937,
#           0.01064818, -0.00751458, -0.02933537, -0.02934481,
#           0.02255381,  0.02908288],
#         [-0.02210003, -0.00759818, -0.03142335, -0.01847057,
#           0.01454475,  0.03072541,  0.0364551 ,  0.01696942,
#           0.02081272,  0.03173153]],
#
#        [[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01024283,  0.03333897, -0.03597488, -0.03536908,
#          -0.01081369, -0.0326545 ,  0.03283647, -0.04393221,
#          -0.04876666,  0.00742389],
#         [-0.00184723, -0.01144005,  0.00779573, -0.02412662,
#           0.01283425,  0.00128699,  0.00562125, -0.0260524 ,
#           0.01661733, -0.01676977],
#         [ 0.03957203,  0.00710893, -0.0075979 , -0.04074937,
#           0.01064818, -0.00751458, -0.02933537, -0.02934481,
#           0.02255381,  0.02908288],
#         [ 0.02957142,  0.02471128, -0.01837429,  0.0158498 ,
#           0.02306229, -0.02692776, -0.00313111, -0.03589997,
#           0.02822948,  0.03533113]],
#
#        [[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01024283,  0.03333897, -0.03597488, -0.03536908,
#          -0.01081369, -0.0326545 ,  0.03283647, -0.04393221,
#          -0.04876666,  0.00742389],
#         [-0.02715744,  0.03964469, -0.03136417, -0.01262212,
#          -0.01147107,  0.00213027,  0.03668224, -0.00152005,
#          -0.04319488,  0.04763806],
#         [ 0.03957203,  0.00710893, -0.0075979 , -0.04074937,
#           0.01064818, -0.00751458, -0.02933537, -0.02934481,
#           0.02255381,  0.02908288],
#         [-0.04353731, -0.00728429, -0.00722538,  0.02872843,
#          -0.00156093,  0.01214174,  0.04146567,  0.04043623,
#          -0.04692615,  0.00022552]],
#
#        [[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [ 0.03412131,  0.0026467 ,  0.00239034, -0.0434318 ,
#           0.01443824, -0.01508506,  0.00075461,  0.03325179,
#          -0.01423013,  0.04840991],
#         [ 0.00021781, -0.04346149,  0.0139836 , -0.03346602,
#           0.02905461,  0.01466518,  0.00028993, -0.01822514,
#           0.00838768,  0.00641532],
#         [ 0.0180509 ,  0.00598923, -0.0107811 ,  0.02346778,
#          -0.01493374,  0.0024802 , -0.04157102, -0.03922095,
#          -0.01164937,  0.01302742],
#         [ 0.00021136,  0.02777952,  0.00707283,  0.00558524,
#           0.0062005 ,  0.03800136, -0.00626737,  0.03701038,
#          -0.00371262, -0.01264449],
#         [ 0.03453023,  0.02171418,  0.03433819, -0.03001566,
#           0.00109099,  0.01496327,  0.04133039,  0.04353194,
#          -0.03640259,  0.01918015]],
#
#        [[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [ 0.03412131,  0.0026467 ,  0.00239034, -0.0434318 ,
#           0.01443824, -0.01508506,  0.00075461,  0.03325179,
#          -0.01423013,  0.04840991],
#         [ 0.00021781, -0.04346149,  0.0139836 , -0.03346602,
#           0.02905461,  0.01466518,  0.00028993, -0.01822514,
#           0.00838768,  0.00641532],
#         [ 0.0180509 ,  0.00598923, -0.0107811 ,  0.02346778,
#          -0.01493374,  0.0024802 , -0.04157102, -0.03922095,
#          -0.01164937,  0.01302742],
#         [ 0.00021136,  0.02777952,  0.00707283,  0.00558524,
#           0.0062005 ,  0.03800136, -0.00626737,  0.03701038,
#          -0.00371262, -0.01264449],
#         [ 0.01246605, -0.01897888,  0.04608292,  0.04049201,
#          -0.03653908,  0.01604536,  0.03092427,  0.00271966,
#           0.04634743, -0.0354188 ]],
#
#        [[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [ 0.02533159,  0.01793212,  0.04781494, -0.01606878,
#          -0.02956846,  0.00743722, -0.04752258, -0.03439424,
#           0.03464453, -0.00890445],
#         [-0.01024283,  0.03333897, -0.03597488, -0.03536908,
#          -0.01081369, -0.0326545 ,  0.03283647, -0.04393221,
#          -0.04876666,  0.00742389],
#         [-0.01170848, -0.03329312,  0.03145567, -0.01566583,
#          -0.00653901, -0.01421287,  0.00603913,  0.00533022,
#          -0.02367845, -0.0261465 ],
#         [ 0.03957203,  0.00710893, -0.0075979 , -0.04074937,
#           0.01064818, -0.00751458, -0.02933537, -0.02934481,
#           0.02255381,  0.02908288],
#         [ 0.02996621,  0.01132675,  0.01877225,  0.01290667,
#           0.03480439,  0.010764  ,  0.04215114, -0.04801343,
#          -0.03261633, -0.04620301]],
#
#        [[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [ 0.01443254, -0.00059109,  0.02459591, -0.01472634,
#           0.03097692,  0.04862757, -0.03100861, -0.0021561 ,
#          -0.02723934,  0.02732838],
#         [ 0.00758068,  0.04907601, -0.01841595,  0.01921212,
#          -0.02457519, -0.01109936,  0.04682324, -0.02308424,
#           0.04419858, -0.03541445],
#         [-0.01363202, -0.02607983, -0.03715511,  0.00619941,
#          -0.03060923, -0.0418553 ,  0.01651058, -0.0473138 ,
#           0.0170945 ,  0.02402968],
#         [ 0.00021136,  0.02777952,  0.00707283,  0.00558524,
#           0.0062005 ,  0.03800136, -0.00626737,  0.03701038,
#          -0.00371262, -0.01264449]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0,  357, 9311, 8336,  365], dtype=int32)

# %%
model.predict(np.array([embedded_docs[0]])) # type: ignore
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# array([[[-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01445148, -0.04827629,  0.02324792, -0.02093254,
#          -0.02930456, -0.01990524,  0.0145203 , -0.02718933,
#          -0.03212751, -0.02670466],
#         [-0.01024283,  0.03333897, -0.03597488, -0.03536908,
#          -0.01081369, -0.0326545 ,  0.03283647, -0.04393221,
#          -0.04876666,  0.00742389],
#         [-0.00184723, -0.01144005,  0.00779573, -0.02412662,
#           0.01283425,  0.00128699,  0.00562125, -0.0260524 ,
#           0.01661733, -0.01676977],
#         [ 0.03957203,  0.00710893, -0.0075979 , -0.04074937,
#           0.01064818, -0.00751458, -0.02933537, -0.02934481,
#           0.02255381,  0.02908288],
#         [-0.02210003, -0.00759818, -0.03142335, -0.01847057,
#           0.01454475,  0.03072541,  0.0364551 ,  0.01696942,
#           0.02081272,  0.03173153]]], dtype=float32)
